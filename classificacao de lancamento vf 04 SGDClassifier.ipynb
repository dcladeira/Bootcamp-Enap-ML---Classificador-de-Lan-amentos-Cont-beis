# %% [markdown]
# vf 04: Classificação se é fato gerador ou não e da categoria (SE, CI, CA) de uma só fez (4 categorias: NÃO, SE, CI, CA) e em 2 etapas, utilizando TF-IDF com limpeza de dados, balanceamento de classes, otimização de hiperparâmetros com cross validation do algoritimo SGDClassifier.

# %% [markdown]
# # Classificação de lançamentos contábeis
#
# 1) Descrição do problema: classificar a despesa pública natureza 339036 (outros serviços - pessoa física) com base no histórico da nota de empenho como fato gerador, ou não, das contribuições previdenciárias.
#
# 2) Descrição da solução: Construção de features com base no texto do histórico das notas de empenho, treinamento e teste para seleção do modelo de classificação com melhor métrica de desempenho.
#
# 3) Fonte de dados: Os dados das notas de empenho estão disponíveis em portais da transparência de diversos órgãos públicos, por exemplo,
# https://www.governotransparente.com.br/acessoinfo/44529487/empenhoportipo. No caso, será utilizada uma base de dados rotulados a partir desses dados públicos.
#
# 4) Variáveis independentes: texto com o histórico da nota de empenho.
#
# 5) Variável dependente. Primeiramente, será classificado apenas como 0 (não é fato gerador) e 1 (é fato gerador). Posteriormente, a classificação incluirá a categoria do segurado: segurado empregado, contribuinte individual, contribuinte individual – condutor autônomo.

# %% [markdown]
# ## 1. Carregamento dos dados e importação das bibliotecas

# %%
# Monta google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Básicos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import joblib

# Pré-processamento
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import spacy
nltk.download('stopwords')
nltk.download('punkt')
spacy.cli.download("pt_core_news_sm")

# Machine Learning
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RepeatedStratifiedKFold
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, f1_score, accuracy_score, confusion_matrix
from sklearn.metrics import balanced_accuracy_score
from sklearn.inspection import permutation_importance
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler

# Configurações
pd.set_option('display.max_colwidth', None)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Importa os dados
df_completo = pd.read_json('/content/drive/My Drive/projeto classificacao de lancamento/dados/despesa liquidada - base completa - texto processado - balanceado.json')
df_completo.head()
# Out:
#                                                                                                                                                                                                descricao  \
# 0                                   Pagamento Referente Aos Serviços De Transporte De Técnicos Durante Supervisão Escolar Nas Escolas Da Zona Rural Deste Município. Referente Ao Mês De Agosto De 2020.
# 1  Pagamento Referente Aos Serviços De Transporte De Técnicos Da Secretaria De Educação, Durante Supervisão Escolar Em Unidades Escolares Da Rede Municipal De Ensino. Referente Ao Mês De Maio De 2020.
# 2                                                                                                                                              Serviços De Transporte De Infraestrutura Deste Municipio.
# 3                                                                         Pagamento Referente Aos Serviços De Transporte De Materiais De Expediente Para Atender As Escolas Da Rede Municipal De Ensino.
# 4                                                                    Serviços De Transportes De Materiais Para Serviços De Infraestrutura Urbana Para Atender As Necessidades As Necessidades Município.
#
#   fato_gerador categoria  \
# 0          Sim        CA
# 1          Sim        CA
# 2          Sim        CA
# 3          Sim        CA
# 4          Sim        CA
#
#                                                            descricao_limpa  \
# 0                     transporte técnicos supervisão escolar escolas deste
# 1  transporte técnicos educação supervisão escolar unidades escolares rede
# 2                                transporte infraestrutura deste municipio
# 3                             transporte materiais expediente escolas rede
# 4    transportes materiais infraestrutura urbana necessidades necessidades
#
#                                                   descricao_lematizada
# 0                 transporte técnico supervisão escolar escola de este
# 1  transporte técnico Educação supervisão escolar unidade escolar rede
# 2                          transporte infraestrutura de este municipio
# 3                           transporte material expediente escola rede
# 4   transporte material infraestrutura urbano necessidade necessidades

# %%
# Construção de dataframe com as colunas de interesse
df = df_completo[['descricao_lematizada', 'fato_gerador', 'categoria']]
df.head()
# Out:
#                                                   descricao_lematizada  \
# 0                 transporte técnico supervisão escolar escola de este
# 1  transporte técnico Educação supervisão escolar unidade escolar rede
# 2                          transporte infraestrutura de este municipio
# 3                           transporte material expediente escola rede
# 4   transporte material infraestrutura urbano necessidade necessidades
#
#   fato_gerador categoria
# 0          Sim        CA
# 1          Sim        CA
# 2          Sim        CA
# 3          Sim        CA
# 4          Sim        CA

# %%
df['categoria'].value_counts()
# Out:
# categoria
# CI     28259
# Não     7873
# CA      2090
# SE       485
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Classificação em 1 etapa (fato gerador e categoria simultaneamente)

# %% [markdown]
# ### 2.1. Otimização de hiperparâmetros

# %%
# %%time
# Amostra de 8000 observações
df_sample = df.sample(8000, random_state=42)

# Separação entre variáveis preditoras e alvo e divisão em treino e teste
X = df_sample['descricao_lematizada']
y = df_sample['categoria']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# Definição dos hiperparâmetros para o Grid Search
param_grid = {
    'tfidf__ngram_range': [(1,1), (1,2)],
    'classifier__penalty': ['l1', 'l2', 'elasticnet'],
    'classifier__alpha': [1e-06, 1e-05, 1e-04]
}

# Pipeline com TF-IDF e regressão logística
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('classifier', SGDClassifier(loss='log_loss', random_state=42))
])

# Busca de hiperparâmetros com validação cruzada
grid_search = GridSearchCV(pipeline, param_grid, cv=5, n_jobs=-1, scoring='f1_weighted')
grid_search.fit(X_train, y_train)

# Melhor modelo encontrado
best_model = grid_search.best_estimator_
print("Melhores hiperparâmetros:", grid_search.best_params_)

# Acurácia do melhor classificador
print(f"F1-Score do melhor modelo: {grid_search.best_score_:.6f}")
# Out:
# Melhores hiperparâmetros: {'classifier__alpha': 1e-06, 'classifier__penalty': 'l1', 'tfidf__ngram_range': (1, 1)}
# F1-Score do melhor modelo: 0.990374
# CPU times: user 1.56 s, sys: 179 ms, total: 1.73 s
# Wall time: 32 s

# %% [markdown]
# ### 2.2. Avaliação do modelo

# %%
# Recuperação do dataset completo e divisão em treino e teste
X = df['descricao_lematizada']
y = df['categoria']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# Ajuste do modelo e predição
best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

# Avaliação
print("F1-Score balanceado:", f1_score(y_test, y_pred, average='weighted'))
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
# Out:
# F1-Score balanceado: 0.9960732441724703
#               precision    recall  f1-score   support
#
#           CA       0.99      0.99      0.99       627
#           CI       1.00      1.00      1.00      8478
#          Não       0.99      1.00      1.00      2362
#           SE       0.90      1.00      0.95       146
#
#     accuracy                           1.00     11613
#    macro avg       0.97      1.00      0.98     11613
# weighted avg       1.00      1.00      1.00     11613

# %% [markdown]
# ### 2.3. Análise das predições do modelo

# %%
# Cálculo das probabilidades de cada classe
prob_pred = best_model.predict_proba(X_test)

# Construção de dataframe para conferência das previsões e respectivas probabilidades
df_check = pd.DataFrame(X_test)
df_check['target'] = y_test
df_check['prediction'] = y_pred
df_check['prob_CA'] = np.round(prob_pred[0:,0],6).tolist()
df_check['prob_CI'] = np.round(prob_pred[0:,1],6).tolist()
df_check['prob_Não'] = np.round(prob_pred[0:,2],6).tolist()
df_check['prob_SE'] = np.round(prob_pred[0:,3],6).tolist()

# Listar as previsões erradas
df_error = df_check[df_check['target'] != df_check['prediction']]
print('Quantidade de previsões erradas:', df_error.shape[0])
df_error
# Out:
# Quantidade de previsões erradas: 46
#                                                                                                                                                                                          descricao_lematizada  \
# 32130                                                                                                                                                                           carro alugar educação de este
# 685                                                                                                                                                                        logisticar saúde de este municipio
# 10367  contribuição financeiro conceder custear despesa taxa arbitragemo fefuspa onde acontecerar jogo selecao baionense futsal contra selecao Goianesia sera realizar Ginasio higino Ramos de este municipio
# 31219                                                         empenho despesa serviço prestar aluguel som iluminação palco estrutura metálico demanr programa cra de este assistência social evento Rosa azul
# 8564                                                                                                                                                                 digitador setor contábil relacionar rede
# 11367                                                                                                                                                                digitador setor contábil relacionar rede
# 33622                                                                                                                                       premiação i concurso miss caipira junina virtual realizar cultura
# 19013                                                                                                               ser marceneiro fornecimento material divisoria casa onde ir funcionar sede seab urbanismo
# 7760                                                                                                                                                                 digitador setor contábil relacionar rede
# 23490                                                                                                                                               ser fornecimento copia documento necessidade sec exec adm
# 28571                                                                                                                                                                digitador setor contábil relacionar rede
# 18055                                                                                                                                                                digitador setor contábil relacionar rede
# 11596                                                                                                                                                                digitador setor contábil relacionar rede
# 103                                                                                                                                              transporte escolar barco técnico Educação supervisão escolar
# 28453                                                                                                                       suporte equipe pedagógico uso ferramenta tecnológico híbrir professor fundamental
# 25795                                                                                                                                                                      ajudar custo juntop combater covid
# 11315                                                                                                                                                                              placar sinalizacao visdual
# 37760                                                                                                   eventual administracao oforneciemnto alimentacao funcionarioso dobrar turno aniversario ano municipio
# 1021                                                                                                                                                                        trasporte movel gabinete prefeito
# 17995                                                                                                                                                                digitador setor contábil relacionar rede
# 34763                                                                                                                proveniente indenização férias adquirir período digitador setor contábil relacionar rede
# 26795                                                                                                                   fornecimento refeição marmitex fornecer agente apoio segurança pandemio coronas vírus
# 31388                                                                                                                           eventual administracao Forneciemnto alimentacao tatico pm policia militar mês
# 9256                                                                                                                                             ser assistencia técnico locação programa recibo relativo ano
# 19929                                                                                                                                                                digitador setor contábil relacionar rede
# 8951                                                                                                                                                                 digitador setor contábil relacionar rede
# 16484                                                                                                           ser reforma ponte sobre igarape colonia Massaranduba fornecimento madeiro conforme contrato n
# 26126                                                                                             ser impressao imagem copia cadastro drp necessidade sec esec desenv economico agroindustriar biocombustivel
# 34374                                                                                                                                ser hotelario destinar hospedagem assessor gabinete prefeito de este adm
# 10842                                                                                                                                                                digitador setor contábil relacionar rede
# 11595                                                                                                                                                                digitador setor contábil relacionar rede
# 35010                                                                                 ser estágio remunerar realizacao acoes ambiental reutilizacao residuo passivo reciclagem fiscalizacao sec exec ambiente
# 18096                                                                                                                                                                sevgico matentcao veiculo destinar saber
# 36                                                          empenho despesa serviço prestar diária veículo tipo retroescavadeirar Modelo bb t x apoio manutenção ruo municipio desenvolvimento infraestrutura
# 27824                                                                                                                 ser frete barco serviço equipe pedagógico visita escola municipal fundamental localizar
# 11614     CI         CA  0.983154  0.015667  0.000764  0.000415
# 8189      CI         CA  0.995137  0.004540  0.000000  0.000322
# 36049    Não         CI  0.000374  0.978996  0.020507  0.000123
# 37476    Não         CI  0.000066  0.958882  0.041005  0.000047
# 10879     CI         SE  0.000033  0.481378  0.000002  0.518587
# 22836     CI         SE  0.000033  0.481378  0.000002  0.518587
# 27634     CI         SE  0.000033  0.481378  0.000002  0.518587
# 3285      CI        Não  0.000000  0.016378  0.983577  0.000046
# 27256     CI         SE  0.000033  0.481378  0.000002  0.518587
# 25327     CI         SE  0.000033  0.481378  0.000002  0.518587

# %% [markdown]
# ## 3. Classificação em 2 etapas (primeiro fato gerador, depois categoria)

# %% [markdown]
# ### 3.1. Classificação de fato gerador

# %% [markdown]
# #### 3.1.1. Otimização de hiperparâmetros

# %%
# %%time
# Dataframe de teste para determinação das melhores técnicas de processamento de texto e melhores hyperparâmetros.
# O método sample estratifica o dataframe proporcionalmente às classes.
df_sample = df.sample(8000, random_state=42)
df_train, df_test = train_test_split(df_sample, test_size=0.3, stratify=df_sample[['fato_gerador', 'categoria']], random_state=42)

# Divisão em treino e teste
X_train, y_train = df_train['descricao_lematizada'], df_train['fato_gerador']
X_test, y_test = df_test['descricao_lematizada'], df_test['fato_gerador']

# Definição dos hiperparâmetros para o Grid Search
param_grid = {
    'tfidf__ngram_range': [(1,1), (1,2)],
    'classifier__penalty': ['l1', 'l2', 'elasticnet'],
    'classifier__alpha': [1e-06, 1e-05, 1e-04]
}

# Pipeline com TF-IDF e regressão logística
pipeline_1 = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('classifier', SGDClassifier(loss='log_loss', random_state=42))
])

# Busca de hiperparâmetros com validação cruzada
grid_search_1 = GridSearchCV(pipeline_1, param_grid, cv=5, n_jobs=-1, scoring='f1_weighted')
grid_search_1.fit(X_train, y_train)

# Melhor modelo encontrado
best_model_1 = grid_search_1.best_estimator_
print(f"Melhores hiperparâmetros: {grid_search_1.best_params_}")

# Acurácia do melhor estimador
print(f"F1-Score: {grid_search_1.best_score_:.6f}")
# Out:
# Melhores hiperparâmetros: {'classifier__alpha': 1e-05, 'classifier__penalty': 'l1', 'tfidf__ngram_range': (1, 1)}
# F1-Score: 0.995706
# CPU times: user 1.77 s, sys: 85.2 ms, total: 1.86 s
# Wall time: 21.5 s

# %% [markdown]
# #### 3.1.2. Avaliação do modelo

# %%
# Recuperação do dataset completo e divisão em treino e teste
df_train, df_test = train_test_split(df, test_size=0.3, stratify=df[['fato_gerador', 'categoria']], random_state=42)

# Divisão em treino e teste
X_train, y_train = df_train['descricao_lematizada'], df_train['fato_gerador']
X_test, y_test = df_test['descricao_lematizada'], df_test['fato_gerador']

# Ajuste do modelo e predição
best_model_1.fit(X_train, y_train)
y_pred = best_model_1.predict(X_test)

# Avaliação
print("F1-Score balanceado:", f1_score(y_test, y_pred, average='weighted'))
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
# Out:
# F1-Score balanceado: 0.9974130031230547
#               precision    recall  f1-score   support
#
#          Não       1.00      0.99      0.99      2362
#          Sim       1.00      1.00      1.00      9251
#
#     accuracy                           1.00     11613
#    macro avg       1.00      0.99      1.00     11613
# weighted avg       1.00      1.00      1.00     11613

# %% [markdown]
# ### 3.2. Classificação de categoria

# %% [markdown]
# #### 3.2.1. Otimização de hiperparâmetros

# %%
# %%time
# Dataframe de teste para determinação das melhores técnicas de processamento de texto e melhores hyperparâmetros.
# O método sample estratifica o dataframe proporcionalmente às classes.
df_sample = df.sample(8000, random_state=42)
df_sample = df_sample[df_sample['fato_gerador'] == 'Sim']
df_train, df_test = train_test_split(df_sample, test_size=0.3, stratify=df_sample[['fato_gerador', 'categoria']], random_state=42)

# Divisão em treino e teste
X_train, y_train = df_train['descricao_lematizada'], df_train['categoria']
X_test, y_test = df_test['descricao_lematizada'], df_test['categoria']

# Definição dos hiperparâmetros para o Grid Search
param_grid = {
    'tfidf__ngram_range': [(1,1), (1,2)],
    'classifier__penalty': ['l1', 'l2', 'elasticnet'],
    'classifier__alpha': [1e-06, 1e-05, 1e-04]
}

# Pipeline com TF-IDF e regressão logística
pipeline_2 = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('classifier', SGDClassifier(loss='log_loss', random_state=42))
])

# Busca de hiperparâmetros com validação cruzada
grid_search_2 = GridSearchCV(pipeline_2, param_grid, cv=5, n_jobs=-1, scoring='f1_weighted')
grid_search_2.fit(X_train, y_train)

# Melhor modelo encontrado
best_model_2 = grid_search_2.best_estimator_
print(f"Melhores hiperparâmetros: {grid_search_2.best_params_}")

# Acurácia do melhor estimador
print(f"F1-Score: {grid_search_2.best_score_:.6f}")
# Out:
# Melhores hiperparâmetros: {'classifier__alpha': 1e-06, 'classifier__penalty': 'l1', 'tfidf__ngram_range': (1, 2)}
# F1-Score: 0.993083
# CPU times: user 1.02 s, sys: 50.1 ms, total: 1.07 s
# Wall time: 8.61 s

# %% [markdown]
# #### 3.2.2. Avaliação do modelo

# %%
# Recuperação do dataset completo, filtro das observações fato_gerador = 1
df_train, df_test = train_test_split(df, test_size=0.3, stratify=df[['fato_gerador', 'categoria']], random_state=42)
df_train = df_train[df_train['fato_gerador'] == 'Sim']
df_test = df_test[df_test['fato_gerador'] == 'Sim']

# Divisão em treino e teste
X_train, y_train = df_train['descricao_lematizada'], df_train['categoria']
X_test, y_test = df_test['descricao_lematizada'], df_test['categoria']

# Ajuste do modelo e predição
best_model_2.fit(X_train, y_train)
y_pred = best_model_2.predict(X_test)

# Avaliação
print("F1-Score balanceado:", f1_score(y_test, y_pred, average='weighted'))
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
# Out:
# F1-Score balanceado: 0.9972377152351308
#               precision    recall  f1-score   support
#
#           CA       1.00      0.99      0.99       627
#           CI       1.00      1.00      1.00      8478
#           SE       0.90      1.00      0.94       146
#
#     accuracy                           1.00      9251
#    macro avg       0.96      1.00      0.98      9251
# weighted avg       1.00      1.00      1.00      9251

# %% [markdown]
# ### 3.3. Combinação dos classificadores de cada etapa
# > O modelo best_model_1 faz a classificação de fato gerador.
#
# > O modelo best_model_2 faz a classificação de categoria.

# %%
# Recuperação do dataset completo e divisão em treino e teste
df_train, df_test = train_test_split(df, test_size=0.3, stratify=df[['fato_gerador', 'categoria']], random_state=42)

df_test['fg_pred'] = best_model_1.predict(df_test['descricao_lematizada'])

df_test_sim = df_test[df_test['fg_pred'] == 'Sim']
df_test_sim['cat_pred'] = best_model_2.predict(df_test_sim['descricao_lematizada'])

df_test_nao = df_test[df_test['fg_pred'] == 'Não']
df_test_nao['cat_pred'] = 'Não'

df_test = pd.concat([df_test_sim, df_test_nao], ignore_index=True)
# Out:
# <ipython-input-13-8ae740b68d9f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_sim['cat_pred'] = best_model_2.predict(df_test_sim['descricao_lematizada'])
# <ipython-input-13-8ae740b68d9f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_nao['cat_pred'] = 'Não'

# %%
# Métricas de avaliação da predição
print("F1-Score balanceado:", f1_score(df_test['categoria'], df_test['cat_pred'], average='weighted'))
print(classification_report(df_test['categoria'], df_test['cat_pred']))
ConfusionMatrixDisplay.from_predictions(df_test['categoria'], df_test['cat_pred'])
# Out:
# F1-Score balanceado: 0.9953852426565413
#               precision    recall  f1-score   support
#
#           CA       0.99      0.99      0.99       627
#           CI       1.00      1.00      1.00      8478
#          Não       1.00      0.99      0.99      2362
#           SE       0.90      1.00      0.94       146
#
#     accuracy                           1.00     11613
#    macro avg       0.97      0.99      0.98     11613
# weighted avg       1.00      1.00      1.00     11613

# %%
# Listar as previsões erradas
df_error = df_test[df_test['categoria'] != df_test['cat_pred']]
print('Quantidade de previsões erradas:', df_error.shape[0])
df_error
# Out:
# Quantidade de previsões erradas: 54
#                                                                                                                                   descricao_lematizada  \
# 12                                                                                                            digitador setor contábil relacionar rede
# 445                                                                                                                                     aluquel social
# 505                                                                                                           digitador setor contábil relacionar rede
# 711                                                                                                                      servico prestar taxista segaf
# 741                                                                                                           digitador setor contábil relacionar rede
# 1514                                                  transporte Kits alimentação escolar Escola marciano correo Miranda localidade felipequar em este
# 1812                                                                                      ser estágio remunerar sec exec desenv urb habitacao relativo
# 1943                                                                                                                loicacao lanchar voadeira Gabinete
# 2167                                                                                                  eventual operador moto nivelador obra Transports
# 2199                                                           ajudar custo conformidade portar participar curso especializacao saude familio beler pa
# 2254                           contribuição financeiro custear despesa realizacao jogo selecao baionense futsal paraense realizar quandra higino Ramos
# 2476                                                           ajudar custo conformidade portar participar curso especializacao saude familio beler pa
# 2553                                                                                                          digitador setor contábil relacionar rede
# 2845                                          p fazer face despesa material consumo Mascaras tecido combate novo coronavirus covid conforme contrato n
# 2896                                                                                                          digitador setor contábil relacionar rede
# 3092                                                                                                  aquisicaor ferio servidor lotar fms relativo ano
# 3510                            contribuição financeiro conceder liga esportivo ituquarense premiacao compeonato ituqurense bairro referir liocalidade
# 3539                                                                                                 ressarcimento passagem tfd devido problema ônibus
# 3582                                                            lacação Moto hondo cor vermelho utilizar prestação transporte técnico Educação em este
# 3697                                                                ser ornamentação fornecimento lanche confraternizacao grupo fortalecimento vinculo
# 4065                                                                                                locaçao veiculo transporte material infraestrutura
# 4214                                                                                                          digitador setor contábil relacionar rede
# 4330                                                                     ajudar finamceiro custear despesa custiar deslocacao alimentacao cidade belem
# 4338                                                                            frete barco transporte material escolar localidade ribeirinha educação
# 4542                                                                                                          digitador setor contábil relacionar rede
# 4870                                                                                                          digitador setor contábil relacionar rede
# 4882   empenho despesa serviço prestar aluguel som iluminação palco estrutura metálico demanr programa cra de este assistência social evento Rosa azul
# 4974                                                                                                          digitador setor contábil relacionar rede
# 5330                                                                                                          digitador setor contábil relacionar rede
# 5404                                                                                                                              despesa devolucao nf
# 5595                                                                                                          digitador setor contábil relacionar rede
# 6726                                                                                                          digitador setor contábil relacionar rede
# 6995                                                                                                          digitador setor contábil relacionar rede
# 7007                                                                ser frete barco transporte material escolar localidade ribeirinha atraves Educação
# 7260                                                                                                          digitador setor contábil relacionar rede
# 7675                                                                                                       alguel veiculo cacamba infraestrutura saber
# 7869                                                                                                  eventual operador moto nivelador obra Transports
# 7933                                                                                                               passagem p municilpal saude tecnico
# 7971                                          p fazer face despesa material consumo Mascaras tecido combate novo coronavirus covid conforme contrato n
# 8105                                                                                                          digitador setor contábil relacionar rede
# 8211                                                                                                         impressão baner foto series foto gabinete
# 8398                                                                                                             alugel imïvel predio conselho tutelar
# 8409                                                                                                             alugel imïvel predio conselho tutelar
# 8627                                                                                      ser estágio remunerar sec exec desenv urb habitação relativo
# 8652                                                                                                          digitador setor contábil relacionar rede
# 8654                                                                                                          digitador setor contábil relacionar rede
# 8704                                                                                                                                    aluquel social
# 8847                                                            ser gerenciamento residuo solir incluir coleta transporte destinacao final praia mapar
# 10181                                                                                                         sevgico matentcao veiculo destinar saber
# 10262                                                                                    ser locação levar trazer correspondencia saude baiao regional
# 10368                      p fazer face despesa servico preparacao fornecimento algodao doce evento programa crianca feliz conforme aditivo contrato n
# 10697                                                        ser marceneiro fornecimento material divisoria casa onde ir funcionar sede seab urbanismo
# 10785                                                                                    ser locação levar trazer correspondencia saude baiao regional
# 11438                                                                                                                       fornecimento bufe gabinete
#
#       fato_gerador categoria fg_pred cat_pred
# 12             Sim        CI     Sim       SE
# 445            Não       Não     Sim       CI
# 505            Sim        CI     Sim       SE
# 711            Sim        CA     Sim       CI
# 741            Sim        CI     Sim       SE
# 1514           Sim        CA     Sim       CI
# 1812           Não       Não     Sim       CI
# 1943           Não       Não     Sim       CI
# 2167           Sim        CA     Sim       CI
# 2199           Não       Não     Sim       CI
# 2254           Não       Não     Sim       CI
# 2476           Não       Não     Sim       CI
# 2553           Sim        CI     Sim       SE
# 2845           Não       Não     Sim       CI
# 2896           Sim        CI     Sim       SE
# 3092           Não       Não     Sim       CI
# 3510           Não       Não     Sim       CI
# 3539           Não       Não     Sim       CI
# 3582           Não       Não     Sim       CA
# 3697           Não       Não     Sim       CI
# 4065           Não       Não     Sim       CA
# 4214           Sim        CI     Sim       SE
# 4330           Não       Não     Sim       CI
# 4338           Sim        CI     Sim       CA
# 4542           Sim        CI     Sim       SE
# 4870           Sim        CI     Sim       SE
# 4882           Não       Não     Sim       CI
# 4974           Sim        CI     Sim       SE
# 5330           Sim        CI     Sim       SE
# 5404           Não       Não     Sim       CI
# 5595           Sim        CI     Sim       SE
# 6726           Sim        CI     Sim       SE
# 6995           Sim        CI     Sim       SE
# 7007           Sim        CI     Sim       CA
# 7260           Sim        CI     Sim       SE
# 7675           Não       Não     Sim       CI
# 7869           Sim        CA     Sim       CI
# 7933           Não       Não     Sim       CI
# 7971           Não       Não     Sim       CI
# 8105           Sim        CI     Sim       SE
# 8211           Não       Não     Sim       CI
# 8398           Não       Não     Sim       CI
# 8409           Não       Não     Sim       CI
# 8627           Não       Não     Sim       CI
# 8652           Sim        CI     Sim       SE
# 8654           Sim        CI     Sim       SE
# 8704           Não       Não     Sim       CI
# 8847           Sim        CI     Sim       CA
# 10181          Sim        CI     Não      Não
# 10262          Sim        CA     Não      Não
# 10368          Sim        CI     Não      Não
# 10697          Sim        CI     Não      Não
# 10785          Sim        CA     Não      Não
# 11438          Sim        CI     Não      Não

# %% [markdown]
# ## 4. Exportação dos melhores modelos

# %%
# Exportação dos melhores modelos
joblib.dump(best_model, '/content/drive/My Drive/projeto classificacao de lancamento/modelos/sgd_best_model.pkl')
joblib.dump(best_model_1, '/content/drive/My Drive/projeto classificacao de lancamento/modelos/sgd_best_model_1.pkl')
joblib.dump(best_model_2, '/content/drive/My Drive/projeto classificacao de lancamento/modelos/sgd_best_model_2.pkl')
# Out:
# ['/content/drive/My Drive/projeto classificacao de lancamento/modelos/sgd_best_model_2.pkl']

# %% [markdown]
# ## 5. Avaliação do melhor modelo de 1 etapa com RepeatedStratifiedKFold

# %%
df_sample = df.sample(8000, random_state=42)
X = df_sample['descricao_lematizada']
y = df_sample['categoria']

# Definição da estratégia de validação cruzada com 5 folds e 20 repetições e avaliação do modelo
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=50, random_state=42)
scores = cross_val_score(best_model, X, y, cv=cv, scoring='f1_weighted')

# Plotando o histograma dos scores com curva de densidade (KDE)
plt.figure(figsize=(7, 4))
sns.histplot(scores, kde=True, bins=20, color='blue', stat='density')
plt.title('Distribution of Cross-Validation Scores (Histogram + KDE)')
plt.xlabel('F1-Score')
plt.ylabel('Density')
plt.grid(True)
plt.show()
print(f"F1-Score médio: {np.mean(scores):.6f}")
print(f"Desvio padrão: {np.std(scores):.6f}")
# Out:
# F1-Score médio: 0.991412
# Desvio padrão: 0.002307

# %% [markdown]
# ## 6. Demonstração do classificador

# %%
# Carregamento dos dados de demonstração
df_demo = pd.read_excel('/content/drive/My Drive/projeto classificacao de lancamento/dados/demo.xlsx')
df_demo.head()
# Out:
#                                                                                                                                                                                Histórico
# 0           PAGAMENTO DO MÉDICO(A)DO PROGRAMA MAIS MÉDICOS PARA O BRASIL QUE ATUA  NO MUNICIPIO(SÃO TOMÉ) DE ACORDO COM A PORTARIA GAB/PMI Nº098/2022,REFERENTE AO MÊS DE JUNHO DE 2024.
# 1        PAGAMENTO DO MÉDICO(A)DO PROGRAMA MAIS MÉDICOS PARA O BRASIL QUE ATUA  NO MUNICIPIO(UBS FLUVIAL) DE ACORDO COM A PORTARIA GAB/PMI Nº315/2023,REFERENTE AO MÊS DE JUNHO DE 2024.
# 2          PAGAMENTO DO MÉDICO(A)DO PROGRAMA MAIS MÉDICOS PARA O BRASIL QUE ATUA  NO MUNICIPIO(MIRITITUBA)DE ACORDO COM A PORTARIA GAB/PMI Nº315/2023,REFERENTE AO MÊS DE JUNHO DE 2024.
# 3            PAGAMENTO DO MÉDICO(A)DO PROGRAMA MAIS MÉDICOS PARA O BRASIL QUE ATUA  NO MUNICIPIO(PIRACANÃ)DE ACORDO COM A PORTARIA GAB/PMI Nº315/2023,REFERENTE AO MÊS DE JUNHO DE 2024.
# 4  PAGAMENTO DO MÉDICO(A)DO PROGRAMA MAIS MÉDICOS PARA O BRASIL QUE ATUA  NO MUNICIPIO(JARDIM DAS ARARAS) DE ACORDO COM A PORTARIA GAB/PMI Nº315/2023,REFERENTE AO MÊS DE JUNHO DE 2024.

# %% [markdown]
# ### 6.1. Pré-processamento

# %%
# Stopwords da biblioteca nltk em português
stop_words_nltk = stopwords.words('portuguese')
meses = ['janeiro', 'fevereiro', 'março', 'abril', 'maio', 'junho', 'julho', 'agosto', 'setembro', 'outubro', 'novembro', 'dezembro']
corpus_stop_words = ['cameta', 'portel', 'laranjal', 'jari', 'garrafão', 'concordia', 'zona', 'rural', 'belém', 'pacaja', 'pacajar', 'anapu',
                     'aluno', 'mês', 'serviços', 'servicos', 'referente', 'prestados', 'prestados', 'pagamento', 'municipal', 'município', 'valor', 'empenha',
                     'favor', 'credor', 'acima', 'ocorrer', 'secretaria', 'ensino', 'mes', 'mês', 'durante', 'junto', 'atender', 'periodo', 'ref', 'm', '``']
stop_words = stop_words_nltk + meses + corpus_stop_words

# %%
# Função para limpeza de texto
def limpa_texto(text, stop_words=[]):
    # Substitui sinais de pontuação por espaço em branco
    text = text.replace('.', ' ')
    text = text.replace(',', ' ')
    text = text.replace(';', ' ')
    text = text.replace(':', ' ')
    text = text.replace('!', ' ')
    text = text.replace('?', ' ')
    text = text.replace('(', ' ')
    text = text.replace(')', ' ')
    text = text.replace('[', ' ')
    text = text.replace(']', ' ')
    text = text.replace('{', ' ')
    text = text.replace('}', ' ')
    text = text.replace('/', ' ')
    text = text.replace('-', ' ')
    text = re.sub(r'[^\w\s]', '', text)
    text = ''.join(word for word in text if not word.isdigit()).lower()         # remove números e coloca em minúscula
    tokens = nltk.word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]                # stopwords
    return ' '.join(tokens)

# %%
# Lematização
nlp = spacy.load('pt_core_news_sm')

def lematiza_spacy(texto):
    doc = nlp(texto)
    palavras_lemmatizadas = [token.lemma_ for token in doc]
    return ' '.join(palavras_lemmatizadas)

# %%
# Aplicação das etapas de pré-processamento
df_demo['descricao_limpa'] = df_demo['Histórico'].apply(lambda x: limpa_texto(x, stop_words))
df_demo['descricao_lematizada'] = df_demo['descricao_limpa'].apply(lambda x: lematiza_spacy(x))
df_demo.head()
# Out:
#                                                                                                                                                                                Histórico  \
# 0           PAGAMENTO DO MÉDICO(A)DO PROGRAMA MAIS MÉDICOS PARA O BRASIL QUE ATUA  NO MUNICIPIO(SÃO TOMÉ) DE ACORDO COM A PORTARIA GAB/PMI Nº098/2022,REFERENTE AO MÊS DE JUNHO DE 2024.
# 1        PAGAMENTO DO MÉDICO(A)DO PROGRAMA MAIS MÉDICOS PARA O BRASIL QUE ATUA  NO MUNICIPIO(UBS FLUVIAL) DE ACORDO COM A PORTARIA GAB/PMI Nº315/2023,REFERENTE AO MÊS DE JUNHO DE 2024.
# 2          PAGAMENTO DO MÉDICO(A)DO PROGRAMA MAIS MÉDICOS PARA O BRASIL QUE ATUA  NO MUNICIPIO(MIRITITUBA)DE ACORDO COM A PORTARIA GAB/PMI Nº315/2023,REFERENTE AO MÊS DE JUNHO DE 2024.
# 3            PAGAMENTO DO MÉDICO(A)DO PROGRAMA MAIS MÉDICOS PARA O BRASIL QUE ATUA  NO MUNICIPIO(PIRACANÃ)DE ACORDO COM A PORTARIA GAB/PMI Nº315/2023,REFERENTE AO MÊS DE JUNHO DE 2024.
# 4  PAGAMENTO DO MÉDICO(A)DO PROGRAMA MAIS MÉDICOS PARA O BRASIL QUE ATUA  NO MUNICIPIO(JARDIM DAS ARARAS) DE ACORDO COM A PORTARIA GAB/PMI Nº315/2023,REFERENTE AO MÊS DE JUNHO DE 2024.
#
#                                                                           descricao_limpa  \
# 0           médico programa médicos brasil atua municipio tomé acordo portaria gab pmi nº
# 1    médico programa médicos brasil atua municipio ubs fluvial acordo portaria gab pmi nº
# 2     médico programa médicos brasil atua municipio miritituba acordo portaria gab pmi nº
# 3       médico programa médicos brasil atua municipio piracanã acordo portaria gab pmi nº
# 4  médico programa médicos brasil atua municipio jardim araras acordo portaria gab pmi nº
#
#                                                                   descricao_lematizada
# 0          médico programa médico Brasil atuar Municipio Tomé acordo portar gab pmi nº
# 1   médico programa médico Brasil atuar municipio ubs fluvial acordo portar gab pmi nº
# 2    médico programa médico Brasil atuar municipio Miritituba acordo portar gab pmi nº
# 3      médico programa médico Brasil atuar municipio piracanã acordo portar gab pmi nº
# 4  médico programa médico Brasil atuar municipio Jardim arara acordo portar gab pmi nº

# %% [markdown]
# ### 6.2. Treinamento e classificação

# %%
# Demonstração da classificação do lançamento para novas observações
demo_sample = df_demo.sample(50, random_state=42)
X_demo = demo_sample['descricao_lematizada']

# %%
y_pred = best_model.predict(X_demo)
demo_sample['categoria'] = y_pred
demo_sample[['Histórico', 'categoria']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                       Histórico  \
# 480                                                                                                                                                                                                                               SERVIÇOS PRESTADOS A SECRETARIA DE SAÚDE NO CARGO DE MÉDICO NO POSTO DE SAÚDE DE MIRITITUBA DURANTE O MES DE JANEIRO DE 2024.
# 449                                                                                                                                                                                                                                    LOCAÇÃO DE IMOVEL LOCALIZADO NA COMUNIDADE DE AGUA BRANCA, PARA O FUNCIONAMENTO DA UBS REFERENTE AO MES DE JANEIRO/2024.
# 475                                                                                                                                                                                                            SERVIÇOS PRESTADOS A SECRETARIA DE SAÚDE NO CARGO DE MÉDICO NAS AÇOES INTINERANTES NAS COMUNIDADES RIBEIRINHAS DURANTE O MES DE JANEIRO DE 2024.
# 434                                                                                                                                                                                                          DESTINADO PARA PAGAMENTO DE MEDICO DO PROGRAMA MAIS MÉDICO QUE ATUA NO MUNICIPIO DE ITAITUBA/PA(BELA VISTA),REFERENTE AO MÊS DE FEVEREIRO DE 2024.
# 368                                                                                                                                        Destinado para pagamento do médico LUIZ TOMAZ DE ALMEIDA SANTOS do pragrama Mais Médico que atua no municipio de Itaituba (CREPURIZINHO), de acordo com a portaria GAB/PMI 282/2019, referente ao mês de MARÇO/2024.
# 55                                                                                                                                                                                                                 PAGAMENTOS DE SERVIÇOS PRESTADOS À SECRETARIA DE SAÚDE NO CARGO DE  MÉDICO NO CENTRO DE SAÚDE DE MIRITITUBA,DURANTE O MÊS DE JUNHO DE  2024.
# 322                                                                                                                 DIARIAS DE SERVIÇOS DE TRANSPORTE  ESCOLAR FLUVIAL,   TIPO LANCHA MOTOR NA ROTA 19: CAKWATPU, EMEF DATIE  BI¦VY, EMEF SAW EXUMBU E EMEF SAWRE BAAY, PARA  DISTRIBUIÇÃO DE MERENDA NAS ESCOLAS INDIGENAS,REFERENTE AO MES DE FEVEREIRO 2024.
# 76                                                                                             DIARIAS DE SERVIÇO DE TRANSPORTE ESCOLAR FLUVIAL, TIPO LANCHA MOTOR, NA ROTA 01: COMUNIDADE NOVO PARAISO/CASTANHO/LAGO DO PAGÃO/LAGO DE ADÃO/ INDEPENDENCIA II, NO MUNICIPIO DE ITAITUBA, ESTADO DO PARÁ, PARA ATENDER OS ALUNOS LOTADOS NA ESCOLA NOVO PARAISO.
# 63                                                                                                                                                   DIARIAS DE SERVIÇO DE TRANSPORTE ESCOLAR FLUVIAL,TIPO   LANCHA MOTOR, NA ROTA 12: COMUNIDADE PEDRA BRANCA,  LAGO DO ITAPURU, LAGO DO SHADA, ROSIMAR E SANTANA, NO  MUNICIPIO DE ITAITUBA, ESTADO DO  PARÁ.
# 2                                                                                                                                                                                 PAGAMENTO DO MÉDICO(A)DO PROGRAMA MAIS MÉDICOS PARA O BRASIL QUE ATUA  NO MUNICIPIO(MIRITITUBA)DE ACORDO COM A PORTARIA GAB/PMI Nº315/2023,REFERENTE AO MÊS DE JUNHO DE 2024.
# 441  DIARIAS DE SERVIÇOS DE TRANSPORTE FLUVIAL, TIPO LANCHA MOTOR NA ROTA 17: COMUNIDADE VILA DO TAPAJOS/PEGAR ALUNOS NA ALDEIA, PARA ATENDER ATENDER ALUNOS LOTADOS EMEF PENEDO. DIARIAS DE SERVIÇO DE TRANSPORTE ESCOLAR, NA ROTA 20: CAKWATPU, EMEF DATIE-BI-VY, EMEF SAW EXUMBU E EMEF SAWRE E EMEF BAAY, EMEF KIRIXI, REFERENTE AO MES DE JANEIRO DE 2024.
# 340                                              DIARIAS DE SERVIÇOS DE TRANSPORTE ESCOLAR FLUVIAL , TIPO LANCHA MOTOR,  NA ROTA 12: COMUNIDADE PEDRA BRANCA, LAGO DO ITAPURU, LAGO DO SHADA,  ROSIMAR E SANTANA, NO MUNICIPIO DE ITAITUBA ESTADO DO PARÁ, PARA  ATENDER OS ALUNOS LOTADOS NA ESCOLA SOLDADO DA BORRACHA, REFERENTE AO  MES DE JANEIRO DE 2024.
# 82                                                                                                                                                                                                                                 DESTINADO DE SERVIÇOS PRESTADOS A SECRETARIA DE SAÚDE NO CARGO DE   MEDICO PLANTONISTA NO HMI DURANTE O MES DE MAIO DE 2024.
# 284                                                                                                                                                                                                                                               DESTINADO AO PAGAMENTO DE SERVIÇOS PRESTADOS A SEMSA NO CARGO DE  MEDICO NA UPA DURANTE MÊS DE MARÇO DE 2024.
# 209                                                                                                                                                                                                                   DESTINADO AO PAGAMENTO DE SERVIÇOS PRESTADOS A SECRETARIA DE SAÚDE NO     CARGO DE MÉDICO PLANTONISTA NO HMI DURANTE O MÊS DE ABRIL/2024.
# 471                                                                                                                                                                                                               SERVIÇOS PRESTADOS A SECRETARIA DE SAÚDE NO CARGO DE MÉDICO  PLANTONISTA NO HOSPITAL MUNICIPAL DE ITAITUBA DURANTE O MES DE JANEIRO  DE 2024.
#
#     categoria
# 480        CI
# 449       Não
# 475        CI
# 434        CI
# 368        CI
# 55         CI
# 322        CA
# 76         CA
# 504        SE
# 347        CI
# 415        CI
# 220       Não
# 117        CI
# 249        CI
# 173        CI
# 93         SE
# 325        CA
# 275        SE
# 342        CA
# 70         CA
# 505        SE
# 9          CI
# 250        CA
# 408        CI
# 423        CI
# 451        CI
# 172        CI
# 30         CI
# 448       Não
# 90         SE
# 381        SE
# 131        CA
# 364        CI
# 73         CA
# 210        SE
# 329        CI
# 369        CI
# 101        CI
# 218        SE
# 154        CI
# 225       Não
# 399        CA
# 63         CA
# 2          CI
# 441        CA
# 340        CA
# 82         SE
# 284        CI
# 209        SE
# 471        SE
